# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('world_population_data.csv')

# %%
data.drop(columns=['cca3'])
# Out:
#      rank           country      continent  2023 population  2022 population  \
# 0       1             India           Asia       1428627663       1417173173
# 1       2             China           Asia       1425671352       1425887337
# 2       3     United States  North America        339996563        338289857
# 3       4         Indonesia           Asia        277534122        275501339
# 4       5          Pakistan           Asia        240485658        235824862
# ..    ...               ...            ...              ...              ...
# 229   230        Montserrat  North America             4386             4390
# 230   231  Falkland Islands  South America             3791             3780
# 231   232              Niue        Oceania             1935             1934
# 232   233           Tokelau        Oceania             1893             1871
# 233   234      Vatican City         Europe              518              510
#
# ...

# %%
df = pd.DataFrame(data)
df.drop('')

# %%
kazakhstan_data = data[data['country'] == 'Kazakhstan']

# %%
kazakhstan_data.drop(columns=['cca3'])
# Out:
#     rank     country continent  2023 population  2022 population  \
# 65    66  Kazakhstan      Asia         19606633         19397998
#
#     2020 population  2015 population  2010 population  2000 population  \
# 65         18979243         17835909         16627837         15236253
#
#     1990 population  1980 population  1970 population  area (km²)  \
# 65         16866563         14172710         12265305   2724900.0
#
#     density (km²) growth rate world percentage
# 65              7       1.08%            0.24%

# %%
print(kazakhstan_data.columns)
# Out:
# Index(['rank', 'cca3', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)', 'density (km²)',
#        'growth rate', 'world percentage'],
#       dtype='object')

# %%
years = [int(col.split()[0]) for col in kazakhstan_data.columns[4:13]]

# %%
years.reverse()

# %%
values = [kazakhstan_data.iloc[0, 4:13]]

# %%
values
# Out:
# [2023 population    19606633
#  2022 population    19397998
#  2020 population    18979243
#  2015 population    17835909
#  2010 population    16627837
#  2000 population    15236253
#  1990 population    16866563
#  1980 population    14172710
#  1970 population    12265305
#  Name: 65, dtype: object]

# %%
kazakhstan_values.append(value for value in values)
new_kazakhstan_values  = []
for value in kazakhstan_values[0]:
    new_kazakhstan_values.append(value)

# %%
new_kazakhstan_values
# Out:
# ['12.3M',
#  '14.2M',
#  '16.9M',
#  '15.2M',
#  '16.6M',
#  '17.8M',
#  '19.0M',
#  '19.4M',
#  '19.6M']

# %%
plt.plot(years, new_kazakhstan_values)
plt.xlabel('Years')
plt.ylabel('Population in Millions')
plt.title('Kazakhstan Population From 1970 till 2023')
plt.grid(True)
plt.savefig('kazakhstan_population_over_years.png')
